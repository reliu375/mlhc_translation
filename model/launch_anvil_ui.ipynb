# %%
import torch
import torch.nn as nn
import numpy as np
import math
import torch.nn.functional as F
import copy
import json
import time
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# !pip install spacy==2.2.3
# !pip install anvil-uplink
# Out:
# Requirement already satisfied: anvil-uplink in /usr/local/lib/python3.7/dist-packages (0.3.36)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from anvil-uplink) (0.16.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from anvil-uplink) (1.15.0)
# Requirement already satisfied: ws4py in /usr/local/lib/python3.7/dist-packages (from anvil-uplink) (0.5.1)
# Requirement already satisfied: argparse in /usr/local/lib/python3.7/dist-packages (from anvil-uplink) (1.4.0)

# %%
import anvil.server
anvil.server.connect("J5EZJULZZEMHTCX47SK4QFGS-KEMRBDIFOMQ7PUZL") # TODO: add key
# Out:
# Connecting to wss://anvil.works/uplink
# Anvil websocket open
# Connected to "Default environment (dev)" as SERVER

# %%
# Citations
# https://towardsdatascience.com/how-to-code-the-transformer-in-pytorch-24db27c8f9ec
# https://pytorch.org/tutorials/beginner/transformer_tutorial.html

# %%
from google.colab import drive 
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%bash
# cd /content/drive/MyDrive/6.871\ NLP\ Project/data/
# ls
# # model_basic_ls.pt
# Out:
# model_12_backup.pt
# model_12.pt
# model_basic_ls_attn.pt
# model_basic_ls_masking.pt
# model_basic_ls.pt
# model_basic.pt
# model_basic_rename.pt
# test_src_sentsent.json
# test_tgt_sentsent.json
# train_src_sentmap.json
# train_src_sentsent.json
# train_tgt_sentmap.json
# train_tgt_sentsent.json

# %%
device = "cuda" # change to "cuda" when moved to google colab?

# %%
### Preprocessing ###

# %%
# Constants for state of data processing
BLANK = 0
ORIGINAL = 1
REPHRASED = 2
TRANSLATED = 3

def process_data(filename, test=False):
    state = ORIGINAL
    original_sents, translated_sents, rephrased_sents = [], [], []
    file = open(filename, 'r')
    while True:
        line = file.readline()
        # print(line, len(line))
        if not line: #EOF
            break 
        if not test:
            if state == ORIGINAL: # Original sentence
                original_sents.append(line.strip())
                state = TRANSLATED
            elif state == TRANSLATED: # Translated sentence
                translated_sents.append(line.strip())
                state = BLANK
            elif state == BLANK: # Blank line
                assert line == '\n' # If assertion fails, something wrong with the file format
                state = ORIGINAL
            else:
                raise ValueError('Unexpected state encountered.')
        else:
            if state == ORIGINAL: # Original sentence
                original_sents.append(line.strip())
                state = REPHRASED
            elif state == REPHRASED: # Translated sentence
                rephrased_sents.append(line.strip())
                state = TRANSLATED
            elif state == TRANSLATED: # Translated sentence
                translated_sents.append(line.strip())
                state = BLANK
            elif state == BLANK: # Blank line
                assert line == '\n' # If assertion fails, something wrong with the file format
                state = ORIGINAL
            else:
                raise ValueError('Unexpected state encountered.')
   
    assert len(original_sents) == len(translated_sents) # all sents should be paired
    if test:
        assert len(original_sents) == len(rephrased_sents)

    return {'original': original_sents, 'translated': translated_sents, 'rephrased': rephrased_sents}

# %%
def process_input_text(text):
  proc_original_sents = sent_tokenize(text)
  # proc_original_sents = []
  # for sent in original_sents:
  #   if sent[-1] == '.' and sent[-2:] != ' .':
  #     proc_original_sents.append(sent[:-1] + " .")
  #   else:
  #     proc_original_sents.append(sent)

  translated_sents = ['translated placeholder' for _ in range(len(proc_original_sents))]
  rephrased_sents = ['rephrased_placeholder' for _ in range(len(proc_original_sents))]
  return {'original': proc_original_sents, 'translated': proc_original_sents, 'rephrased': proc_original_sents}

# %%
# %%time
train = process_data('/content/drive/MyDrive/6.871 NLP Project/MedLane/train(12809)_new.txt')
test = process_data('/content/drive/MyDrive/6.871 NLP Project/MedLane/test(2030)_new.txt', test=True)
# Out:
# CPU times: user 29.6 ms, sys: 1.65 ms, total: 31.3 ms
# Wall time: 36 ms

# %%
test['translated'] = [sentence[2:] for sentence in test['translated']]

# %%
import spacy
from collections import Counter

# %%
# %%time
def tokenize_and_build_vocab(corpus, tokenization_func, special_tokens, min_freq = 0):
    vocab_counter = Counter()
    tokenized_sent = []
    for (i, sent) in enumerate(corpus):
        if i % 200 == 0: 
          print('reached corpus sentence ' + str(i))
        token_list = tokenization_func(sent)
        tokenized_sent.append(token_list)
        vocab_counter.update(token_list)
        
    vocab_to_ix = {vocab: ix + len(special_tokens) for ix, (vocab, freq) in enumerate(vocab_counter.most_common()) if freq >= min_freq}
    
    for tok, ix in special_tokens.items():
        vocab_to_ix[tok] = ix
        
    return tokenized_sent, dict(vocab_counter.most_common()), vocab_to_ix

def tokenize(lang_model, sentence):
    sentence = sentence.lower()
    sentence = [tok.text for tok in lang_model.tokenizer(sentence)]

    return sentence
print('started')
lang_model = spacy.load('en_core_web_sm', disable=['tagger', 'parser', 'ner'])
print('lang model built')
tokenization_func = lambda x: tokenize(lang_model, x)
special_tokens = {'<PAD>': 0, '<UNK>': 1, '<SOS>': 2, '<EOS>': 3}
print('created tokenizer')
# Out:
# started
# lang model built
# created tokenizer
# CPU times: user 659 ms, sys: 96.8 ms, total: 756 ms
# Wall time: 754 ms

# %%
# train_src_sent, _, src_vocab_to_ix = tokenize_and_build_vocab(train['original'], tokenization_func, special_tokens) #5
# print('train src sentence done')
# train_tgt_sent, _, tgt_vocab_to_ix = tokenize_and_build_vocab(train['translated'], tokenization_func, special_tokens)
# print('train tgt sentence done')

# test_src_sent, _, _ = tokenize_and_build_vocab(test['original'], tokenization_func, special_tokens)
# print('test src sentence done')
# test_tgt_sent, _, _ = tokenize_and_build_vocab(test['translated'], tokenization_func, special_tokens)
# print('test tgt sentence done')

# %%
with open("/content/drive/MyDrive/6.871 NLP Project/data/train_src_sentsent.json") as f:  
  train_src_sent = json.load(f)

with open("/content/drive/MyDrive/6.871 NLP Project/data/train_src_sentmap.json") as f:  
  src_vocab_to_ix = json.load(f)

with open("/content/drive/MyDrive/6.871 NLP Project/data/train_tgt_sentsent.json") as f:  
  train_tgt_sent = json.load(f)

with open("/content/drive/MyDrive/6.871 NLP Project/data/train_tgt_sentmap.json") as f:  
  tgt_vocab_to_ix = json.load(f)


with open("/content/drive/MyDrive/6.871 NLP Project/data/test_src_sentsent.json") as f:  
  test_src_sent = json.load(f)

with open("/content/drive/MyDrive/6.871 NLP Project/data/test_tgt_sentsent.json") as f:  
  test_tgt_sent = json.load(f)

# %%
test_tgt_sent = [sent[1:] for sent in test_tgt_sent]

# %%
print(len(src_vocab_to_ix))
print(len(tgt_vocab_to_ix))
# Out:
# 12603
# 12225

# %%
from torch.utils import data

# These IDs are reserved.
PAD_INDEX = 0
UNK_INDEX = 1
SOS_INDEX = 2
EOS_INDEX = 3

class MTDataset(data.Dataset):
    def __init__(self, src_sents, src_vocab_map, tgt_sents, tgt_vocab_map, num_samples=1.):
        self.src_sents = src_sents[:int(len(src_sents) * num_samples)]
        self.tgt_sents = tgt_sents[:int(len(src_sents) * num_samples)]
        self.src_vocab_to_ix = src_vocab_map
        self.src_ix_to_vocab = {v: k for k, v in src_vocab_map.items()}
        self.tgt_vocab_to_ix = tgt_vocab_map
        self.tgt_ix_to_vocab = {v: k for k, v in tgt_vocab_map.items()}
        
        self.max_src_seq_len = 146 #max([len(sent) for sent in src_sents]) + 2
        self.max_tgt_seq_len = 146 #max(max([len(sent) for sent in tgt_sents]) + 2, self.max_src_seq_len)
        
        assert len(self.src_sents) == len(self.tgt_sents)
        
    def __getitem__(self, index):
        src_sent = self.src_sents[index]
        src_len = len(src_sent) + 2 # including <SOS> <EOS>
        src_ids = []
        for w in src_sent:
            if w not in self.src_vocab_to_ix:
                src_ids.append(UNK_INDEX)
            else:
                src_ids.append(self.src_vocab_to_ix[w])
        
        src_id = ([SOS_INDEX] + src_ids + [EOS_INDEX] + [PAD_INDEX] *
              (self.max_src_seq_len - src_len))
        
        tgt_sent = self.tgt_sents[index]
        tgt_len = len(tgt_sent) + 2
        tgt_ids = []
        for w in tgt_sent:
            if w not in self.tgt_vocab_to_ix:
                tgt_ids.append(UNK_INDEX)
            else:
                tgt_ids.append(self.tgt_vocab_to_ix[w])
                
        tgt_id = ([SOS_INDEX] + tgt_ids + [EOS_INDEX] + [PAD_INDEX] *
              (self.max_tgt_seq_len - tgt_len))
        
        
        return torch.tensor(src_id), src_len, torch.tensor(tgt_id), tgt_len
    
    def __len__(self):
        return len(self.src_sents)

# %%
batch_size = 32
train_set = MTDataset(train_src_sent, src_vocab_to_ix, train_tgt_sent, tgt_vocab_to_ix, 1) #3, #4
test_set  = MTDataset(test_src_sent, src_vocab_to_ix, test_tgt_sent, tgt_vocab_to_ix, 1) #3, #4

train_data_loader = data.DataLoader(train_set, batch_size=32, num_workers = 8, shuffle=True) #2
test_data_loader = data.DataLoader(test_set, batch_size=1, num_workers = 8, shuffle=False) #2
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
print(train_set.max_src_seq_len)
print(train_set.max_tgt_seq_len)
print(test_set.max_src_seq_len)
print(test_set.max_tgt_seq_len)
# Out:
# 146
# 146
# 146
# 146

# %%
# Model Code

# %%
# Masking functions
def subsequent_mask(size):
    attn_shape = (1, size, size)
    subsequent_mask = np.triu(np.ones(attn_shape), k=1).astype('uint8')
    return torch.from_numpy(subsequent_mask) == 0

def make_std_mask(tgt, pad):
    "Create a mask to hide padding and future words."
    tgt_mask = (tgt != pad).unsqueeze(-2)
    tgt_mask = tgt_mask & Variable(
        subsequent_mask(tgt.size(-1)).type_as(tgt_mask.data))
    return tgt_mask

# %%
# Loss function/perplexity
import math
import time

class SimpleLossCompute:
  """A simple loss compute and train function."""

  def __init__(self, generator, criterion, opt=None):
    self.generator = generator
    self.criterion = criterion
    self.opt = opt

  def __call__(self, x, y, norm):
    x = self.generator(x)
    loss = self.criterion(x.contiguous().view(-1, x.size(-1)),
                          y.contiguous().view(-1))
    loss = loss / norm

    if self.opt is not None:  # training mode
      loss.backward()          
      self.opt.step()
      self.opt.zero_grad()

    return loss.data.item() * norm

def run_epoch(data_loader, model, loss_compute, print_every = 10):
    "Standard Training and Logging Function"
    criterion = nn.NLLLoss(reduction="sum", ignore_index=PAD_INDEX)
    start = time.time()
    total_tokens = 0
    total_loss = 0
    tokens = 0
    for i, batch in enumerate(data_loader):
        srcs, src_lens, tgts, tgt_lens = batch
        
        srcs_mask = srcs.unsqueeze(-2) != PAD_INDEX
        tgts_mask = make_std_mask(tgts[:,:-1], PAD_INDEX)

        del tgt_lens

        # print('source ids shape', srcs.shape)
        # print('target ids shape', tgts[:,:-1].shape)
        # print('source masks shape', srcs_mask.shape)
        # print('target masks shape', tgts_mask.shape)

        out = model.forward(srcs.to(device), tgts[:,:-1].to(device), srcs_mask.to(device), tgts_mask.to(device))
        # print(out.size()) # seq_len = 47
        # print(tgts[:,1:].size()) # (bs x 46 x ...)

        loss = loss_compute(out, tgts[:,1:].to(device), norm=srcs.size(0))
        total_loss += loss
        total_tokens += (tgts[:,1:] != PAD_INDEX).data.sum().item()
        
        if model.training and i % print_every == 0:
          print("Epoch Step: %d Loss: %f" % (i, loss / srcs.size(0)))
          print("Epoch Step: %d Perplexity: %f" % (i, math.exp(total_loss / float(total_tokens))))

    return math.exp(total_loss / float(total_tokens))

# %%
class NoamOpt:
    "Optim wrapper that implements rate."
    def __init__(self, model_size, factor, warmup, optimizer):
        self.optimizer = optimizer
        self._step = 0
        self.warmup = warmup
        self.factor = factor
        self.model_size = model_size
        self._rate = 0
        
    def step(self):
        "Update parameters and rate"
        self._step += 1
        rate = self.rate()
        for p in self.optimizer.param_groups:
            p['lr'] = rate
        self._rate = rate
        self.optimizer.step()
        
    def rate(self, step = None):
        "Implement `lrate` above"
        if step is None:
            step = self._step
        return self.factor * \
            (self.model_size ** (-0.5) *
            min(step ** (-0.5), step * self.warmup ** (-1.5)))

class LabelSmoothing(nn.Module):
    "Implement label smoothing."
    def __init__(self, vocab_size, padding_idx, smoothing=0.0):
        super(LabelSmoothing, self).__init__()
        self.criterion = nn.KLDivLoss(size_average=False)
        self.padding_idx = padding_idx
        self.confidence = 1.0 - smoothing
        self.smoothing = smoothing
        self.vocab_size = vocab_size
        self.true_dist = None
        
    def forward(self, x, target):
        assert x.size(1) == self.vocab_size
        true_dist = x.data.clone()
        true_dist.fill_(self.smoothing / (self.vocab_size - 2))
        true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence)
        true_dist[:, self.padding_idx] = 0
        mask = torch.nonzero(target.data == self.padding_idx)
        if mask.dim() > 0:
            true_dist.index_fill_(0, mask.squeeze(), 0.0)
        self.true_dist = true_dist
        return self.criterion(x, Variable(true_dist, requires_grad=False))

# %%
def train(model, num_epochs, learning_rate, print_every):
  # Set `ignore_index` as PAD_INDEX so that pad tokens won't be included when
  # computing the loss.
  criterion = LabelSmoothing(len(tgt_vocab_to_ix), PAD_INDEX, smoothing=0.1)
  optim = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.98), eps=1e-9)
  noam_optim = NoamOpt(model.d_model, 1, 800, optim)

  # Keep track of dev ppl for each epoch.
  dev_ppls = []

  for epoch in range(num_epochs):
    print("Epoch", epoch)

    model.train()
    train_ppl = run_epoch(data_loader=train_data_loader, model=model,
                          loss_compute=SimpleLossCompute(model.generator,
                                                         criterion, optim),
                          print_every=print_every)
        
    model.eval()
    with torch.no_grad():      
      dev_ppl = run_epoch(data_loader=test_data_loader, model=model,
                          loss_compute=SimpleLossCompute(model.generator,
                                                         criterion, None),
                          print_every=print_every)
      print("Validation perplexity: %f" % dev_ppl)
      dev_ppls.append(dev_ppl)

  # torch.save(model, 'drive/My Drive/MIT/6.864/6.864 FP/transformer/model.pt')
        
  return dev_ppls

# %%
# Greedy decode algorithm:
def greedy_decode(model, src, src_mask, max_len, start_symbol):
    encoder_out = model.encode(src, src_mask)
    ys = torch.ones(1, 1).fill_(start_symbol).type_as(src.data)
    
    output = []
    for i in range(max_len-1):
        out = model.decode(ys, encoder_out, src_mask, subsequent_mask(ys.size(1)).type_as(src.data))
        prob = model.generator(out[:, -1])
        _, next_word = torch.max(prob, dim = 1)
        next_word = next_word.data[0]
        if next_word == EOS_INDEX: 
            break
        output.append(next_word)    
        ys = torch.cat([ys, 
                        torch.ones(1, 1).type_as(src.data).fill_(next_word)], dim=1)
    
    return output

# %%
# Decoding with Beam Search
import copy
def beam_search_decode(model, src, src_mask, max_len, start_symbol, num_beams=2):

  remaining_beams = num_beams
  encoder_out = model.encode(src, src_mask)
  beam_ys = [torch.ones(1, 1).fill_(start_symbol).type_as(src.data) for j in range(remaining_beams)]
  beam_probs = [0 for j in range(remaining_beams)]
  
  beam_search_final_outputs = []
  
  for i in range(max_len-1):
    # get results of all beam expansions here
    # will store results of 2 * remaining_beams after j loop

    # list of lists
    # each element is of the form [probability, token indices]
    all_candidate_beam_results = []
    # print(beam_probs)
    
    for j in range(remaining_beams):
      beam_prob_so_far = beam_probs[j] # product of beam token logits so far
      beam_ys_so_far = beam_ys[j]

      beam_out = model.decode(beam_ys_so_far, encoder_out, src_mask, 
                              subsequent_mask(beam_ys_so_far.size(1)).type_as(src.data))
      beam_prob = model.generator(beam_out[:, -1])

      # get the top remaining_beams next words for this beam
      beam_top_next_token_probs, beam_top_next_token_idxs = torch.topk(beam_prob, 
                                                                       remaining_beams, 
                                                                       dim=1)

      # for each new beam candidate, calculate its prob and next token id
      for k in range(remaining_beams):
        candidate_next_token_prob = beam_top_next_token_probs[0, k].item()
        candidate_next_token_idx = beam_top_next_token_idxs[0, k].item()

        # add probs because is log softmax
        candidate_beam_prob = beam_prob_so_far + candidate_next_token_prob
        candidate_output = torch.cat([beam_ys_so_far, 
                                      torch.ones(1, 1).type_as(src.data).fill_(candidate_next_token_idx)],
                                     dim=1)
        
        # add data for this candidate beam to all_candidate_beam_results if it's new
        if not(any(elt[0] == candidate_beam_prob for elt in all_candidate_beam_results)):
          all_candidate_beam_results.append([candidate_beam_prob, candidate_output])

    # after first j-loop
    # sort candidate beams by decreasing probability
    all_candidate_beam_results.sort(reverse = True, key = lambda x: float(x[0]))
   

    remaining_beams_copy = remaining_beams
    new_beam_ys = []
    new_beam_probs = []

    for j in range(remaining_beams_copy):
      if remaining_beams > 0:
        # get the last token of the candidate beam
        beam_candidate = all_candidate_beam_results[j]
        beam_candidate_last_tok = beam_candidate[1].data[0, -1].item()

        # if it's an EOS, add the beam candidate to beam_search_final_outputs
        if beam_candidate_last_tok == EOS_INDEX:
          beam_search_final_outputs.append(beam_candidate)
           # decrement remaining_beams
          # print('EOS!')
          remaining_beams -= 1

        elif i == max_len - 2: # we're at the end of the sequence anyway
          # add the top (remaining_beams) sequences to beam_search_final_outputs
          beam_search_final_outputs.append(beam_candidate)
          remaining_beams -= 1
        else:
          # add to new_beam_probs and new_beam_ys
          new_beam_probs.append(beam_candidate[0])
          new_beam_ys.append(beam_candidate[1])
  
    # reset beam_probs and beam_ys
    beam_probs = copy.deepcopy(new_beam_probs)
    beam_ys = copy.deepcopy(new_beam_ys)

    if remaining_beams == 0:
      break

  # pick the top beam by prob and return its output token indices
  beam_search_final_outputs.sort(reverse=True, key = lambda x: x[0])
  # for m in range(len(beam_search_final_outputs)):
  #   ix_to_vocab = train_set.tgt_ix_to_vocab
  #   out = list(beam_search_final_outputs[m][1][0].data)[1:-1]
  #   out_sent = "".join([ix_to_vocab[ix.item()] if ix != UNK_INDEX else 'x' for ix in out])
  #   out_sent = " ".join([char for char in out_sent])
  #   print(out_sent)
  
  # print('---')

  return list(beam_search_final_outputs[0][1][0].data)[1:-1]

# %%
# Model Implementation

# %%
from torch.autograd import Variable

class PositionalEncoder(nn.Module):
  def __init__(self, d_model, max_seq_len=146):
    super().__init__()
    self.d_model = d_model
        
    # create constant 'pe' matrix with values dependant on 
    # pos and i
    pe = torch.zeros(max_seq_len, d_model)
    for pos in range(max_seq_len):
      for i in range(0, d_model, 2):
        pe[pos, i] = math.sin(pos / (10000 ** ((2 * i)/d_model)))
        pe[pos, i + 1] = math.cos(pos / (10000 ** ((2 * (i + 1))/d_model)))

    pe = pe.unsqueeze(0)
    self.register_buffer('pe', pe)

  def forward(self, x):
    x = x * math.sqrt(self.d_model) # conflict possible, check this line

    seq_len = x.size(1)
    x = x + Variable(self.pe[:,:seq_len], requires_grad=False)# .cuda()
    return x

# %%
def attention(q, k, v, d_k, mask=None, dropout=None):
  scores = torch.matmul(q, k.transpose(-2, -1)) / math.sqrt(d_k)

  if mask is not None:
    # print('mask size ', mask.size())
    # print('q size ', q.size())
    # print("scores", scores.size())
    mask = mask.unsqueeze(1)
    # print("mask", mask.size(), '\n')
    scores = scores.masked_fill(mask==0, -1e9) # approximation

  scores = F.softmax(scores, dim=-1)

  if dropout is not None:
    scores = dropout(scores)

  return torch.matmul(scores, v)

class MultiHeadAttention(nn.Module):
  def __init__(self, heads, d_model, dropout = 0.1):
    super().__init__()
    self.d_model = d_model
    self.d_k = d_model // heads
    self.heads = heads

    self.query = nn.Linear(d_model, d_model)
    self.key = nn.Linear(d_model, d_model)
    self.value = nn.Linear(d_model, d_model)
    self.dropout = nn.Dropout(dropout)
    self.out = nn.Linear(d_model, d_model)

  def forward(self, q, k, v, mask=None):
    bs = q.size(0)

    q = self.query(q).view(bs, -1, self.heads, self.d_k)
    k = self.key(k).view(bs, -1, self.heads, self.d_k)
    v = self.value(v).view(bs, -1, self.heads, self.d_k)

    q = q.transpose(1, 2)
    k = k.transpose(1, 2)
    v = v.transpose(1, 2)
    scores = attention(q, k, v, self.d_k, mask, self.dropout)

    concat = scores.transpose(1, 2).contiguous().view(bs, -1, self.d_model)

    return self.out(concat)

# %%
class FeedForward(nn.Module):
  def __init__(self, d_model, d_ff=2048, dropout=0.1):
    super().__init__()

    self.l1 = nn.Linear(d_model, d_ff)
    self.dropout = nn.Dropout(dropout)
    self.l2 = nn.Linear(d_ff, d_model)

  def forward(self, x):
    x = self.dropout(F.relu(self.l1(x)))
    return self.l2(x)

# %%
class LayerNorm(nn.Module):
  def __init__(self, d_model, eps=1e-6):
    super().__init__()

    self.size = d_model

    self.alpha = nn.Parameter(torch.ones(self.size))
    self.bias = nn.Parameter(torch.zeros(self.size))
    self.eps = eps

  def forward(self, x):
    norm = self.alpha * (x - x.mean(dim=-1, keepdim=True)) / (x.std(dim=-1, keepdim=True) + self.eps) + self.bias
    return norm

# %%
class EncoderLayer(nn.Module):
  def __init__(self, d_model, heads, d_ff = 2048, dropout=0.1):
    super().__init__()
    self.ln1 = LayerNorm(d_model)
    self.ln2 = LayerNorm(d_model)
    self.attn = MultiHeadAttention(heads, d_model, dropout)
    self.ff = FeedForward(d_model, d_ff, dropout)
    self.d1 = nn.Dropout(dropout)
    self.d2 = nn.Dropout(dropout)

  def forward(self, x, mask):
    x2 = self.ln1(x)
    x = x + self.d1(self.attn(x2, x2, x2, mask))
    x2 = self.ln2(x)
    x = x + self.d2(self.ff(x2))
    return x

class DecoderLayer(nn.Module):
  def __init__(self, d_model, heads, d_ff = 2048, dropout=0.1):
    super().__init__()
    self.ln1 = LayerNorm(d_model)
    self.ln2 = LayerNorm(d_model)
    self.ln3 = LayerNorm(d_model)

    self.d1 = nn.Dropout(dropout)
    self.d2 = nn.Dropout(dropout)
    self.d3 = nn.Dropout(dropout)

    self.attn1 = MultiHeadAttention(heads, d_model, dropout)
    self.attn2 = MultiHeadAttention(heads, d_model, dropout)
    self.ff = FeedForward(d_model, d_ff, dropout)
  
  def forward(self, x, encoder_out, src_mask, tgt_mask):
    x2 = self.ln1(x)
    # print('x2 shape ', x2.shape)
    x = x + self.d1(self.attn1(x2, x2, x2, tgt_mask))
    x2 = self.ln2(x)
    x = x + self.d2(self.attn2(x2, encoder_out, encoder_out, src_mask))
    x2 = self.ln3(x)
    return x + self.d3(self.ff(x2))

# %%
import copy

def clone(module, N):
  return nn.ModuleList([copy.deepcopy(module) for _ in range(N)])

class Encoder(nn.Module):
  def __init__(self, vocab_size, d_model, N, heads, d_ff = 2048, dropout=0.1):
    super().__init__()
    self.N = N
    self.embed = nn.Embedding(vocab_size, d_model)
    self.pe = PositionalEncoder(d_model)
    self.layers = clone(EncoderLayer(d_model, heads, d_ff, dropout), self.N)
    self.ln = LayerNorm(d_model)

  def forward(self, src, mask):
    x = self.embed(src)
    x = self.pe(x)
    for i in range(self.N):
      x = self.layers[i](x, mask)

    return self.ln(x)

class Decoder(nn.Module):
  def __init__(self, vocab_size, d_model, N, heads, d_ff = 2048, dropout=0.1):
    super().__init__()
    self.N = N
    self.embed = nn.Embedding(vocab_size, d_model)
    self.pe = PositionalEncoder(d_model)
    self.layers = clone(DecoderLayer(d_model, heads, d_ff, dropout), self.N)
    self.ln = LayerNorm(d_model)

  def forward(self, tgt, encoder_out, src_mask, tgt_mask):
    x = self.embed(tgt)
    x = self.pe(x)
    for i in range(self.N):
      x = self.layers[i](x, encoder_out, src_mask, tgt_mask)
    return self.ln(x)

# %%
class Generator(nn.Module):
  def __init__(self, d_model, vocab_size):
    super().__init__()
    self.proj = nn.Linear(d_model, vocab_size)

  def forward(self, x):
    return F.log_softmax(self.proj(x), dim=-1)

# %%
# Full Model

# %%
class ClinicalTextTranslationModel(nn.Module):
    """ Model class wrapping encoder + intermediate layers + decoder """
    def __init__(self, src_vocab_size, tgt_vocab_size, d_model, N, heads, d_ff = 2048, dropout=0.1, intermediate_layers=None):
        
        #self, hidden_size, num_heads, N, ff_size, dropout, max_seq_len,
        #         intermediate_layers, src_vocab_size, tgt_vocab_size):
        
        super().__init__()
        self.d_model = d_model
        self.encoder = Encoder(src_vocab_size, d_model, N, heads, d_ff = 2048, dropout=0.1)
        self.intermediate_layers = intermediate_layers
        self.decoder = Decoder(tgt_vocab_size, d_model, N, heads, d_ff = 2048, dropout=0.1)
        
        self.generator = Generator(d_model, tgt_vocab_size)
    
    def forward(self, src, tgt, src_mask, tgt_mask):
        encoder_output = self.encoder(src, src_mask)
        
        intermediate_layer_output = encoder_output
        
        if self.intermediate_layers is not None:
            intermediate_layer_output = self.intermediate_layers(intermediate_output)
            
        decoder_output = self.decoder(tgt, intermediate_layer_output, src_mask, tgt_mask)
        
        return decoder_output
    
    def encode(self, src, src_mask):
        encoder_output = self.encoder(src, src_mask)
        
        intermediate_layer_output = encoder_output
        
        if self.intermediate_layers is not None:
            intermediate_layer_output = self.intermediate_layers(intermediate_output)
        
        return intermediate_layer_output
        
    def decode(self, tgt, intermediate_layer_output, src_mask,  tgt_mask):
        decoder_output = self.decoder(tgt, intermediate_layer_output, src_mask, tgt_mask)
        return decoder_output

# %%
def get_translation(model, data_loader, decoder, max_iters):
  translated_sentences = []

  for i, batch in enumerate(data_loader):
    if i >= max_iters: break
    srcs, src_lens, tgts, tgt_lens = batch
          
    srcs_mask = srcs.unsqueeze(-2) != PAD_INDEX

    src_ix_to_vocab = train_set.src_ix_to_vocab

    src_sent = " ".join([src_ix_to_vocab[ix.item()] for ix in srcs[0]])
    print('Source sent: ', src_sent)    
    
    print("srcs[0]:", len(srcs[0]))
    print("srcs_mask:", len(srcs_mask))
    print("srcs_mask[0]:", len(srcs_mask[0]))
    # print("srcs_mask[1]:", len(srcs_mask[1]))
    out = decoder(model, srcs.to(device), srcs_mask.to(device), 146, SOS_INDEX)

    tgts = tgts[0,1:]
    print("WHERE:", np.where(tgts == EOS_INDEX)[0][0])
    tgts = tgts[:np.where(tgts == EOS_INDEX)[0][0]]
    
    tgt_ix_to_vocab = train_set.tgt_ix_to_vocab
    
    tgt_sent = " ".join([tgt_ix_to_vocab[ix.item()] for ix in tgts])
    out_sent = " ".join([tgt_ix_to_vocab[ix.item()] for ix in out])
    print('Target Tokens: ', tgt_sent)
    print('Out tokens: ', out_sent)

    translated_sentences.append(out_sent)

  return translated_sentences

def combine(sentences):
  s = ""
  for sent in sentences:
    proc_sent = sent
    # if sent[-2:] == ' .':
    #   proc_sent = sent[:-2] + "."
    s += proc_sent
    s += ' '

  print("COMBINED:", s)
  return s

# %%
model = torch.load("/content/drive/MyDrive/6.871 NLP Project/data/model_basic_ls.pt")

# %%
@anvil.server.callable
def translate(text):
  inp_data = process_input_text(text)
  print(inp_data)
  data_src_sent, _, _ = tokenize_and_build_vocab(inp_data['original'], tokenization_func, special_tokens) 
  data_tgt_sent, _, _ = tokenize_and_build_vocab(inp_data['translated'], tokenization_func, special_tokens)

  print("DATA:", data_src_sent)
  print("TRAIN:", test_src_sent)

  data_set = MTDataset(data_src_sent, src_vocab_to_ix, data_tgt_sent, tgt_vocab_to_ix, 1) 
  data_loader = data.DataLoader(data_set, batch_size=1, num_workers = 8, shuffle=False) 
  sentences = get_translation(model, data_loader, greedy_decode, 25000) # TODO: can also use beam_search_decode instead!!
  print("SENTENCES:", sentences)
  translation = combine(sentences)
  
  return translation

# %%
# translate("He has hypertension. Take in for CXR. Dr. seuss will see tmr.")
# Out:
# {'original': ['He has hypertension.', 'Take in for CXR.', 'Dr. seuss will see tmr.'], 'translated': ['He has hypertension.', 'Take in for CXR.', 'Dr. seuss will see tmr.'], 'rephrased': ['He has hypertension.', 'Take in for CXR.', 'Dr. seuss will see tmr.']}
# reached corpus sentence 0
# reached corpus sentence 0
# DATA: [['he', 'has', 'hypertension', '.'], ['take', 'in', 'for', 'cxr', '.'], ['dr', '.', 'seuss', 'will', 'see', 'tmr', '.']]
# TRAIN: [['weaned', 'off', 'vent', 'to', 'cpap', 'and', 'was', 'extubated', 'in', 'the', 'afternoon', 'on', '9', '-', '2', 'by', 'the', 'pulmonary', 'team', '.'], ['she', 'was', 'intubated', 'and', 'was', 'resuscitated', 'after', '10', '-', '22', 'minutes', 'of', 'pea', 'arrest', '.'], ['he', 'was', 'given', 'succinyl', 'choline', 'and', 'etomidate', 'for', 'intubation', '.'], ['had', 'post', '-', 'op', 'anemia', 'and', 'was', 'transfused', 'with', 'appropriate', 'effect', '.'], ['the', 'patient', 'was', 'maintained', 'on', 'logroll', 'precautions', 'until', 'tl', 'spine', 'films', 'were', 'obtained', 'and', 'read', 'as', 'negative', '.'], ['a', 'line', 'placed', '&', 'sent', 'to', 'mri', 'per', 'neurosurgical', 'recommendations', '.'], ['this', 'gradually', 'cleared', 'when', 'the', 'pt', 'was', 'extubated', 'and', 'by', 'the', 'last', 'few', 'days', 'of', 'admission', 'her', 'mental', 'status', 'was', 'at', 'baseline', '.'], ['per', 'patient', ',', 'he', 'took', 'pepto', '-', 'bismol', '3', 'times', 'earlier', 'in', 'the', 'weeks', 'for', '3', 'days', '.'], ['pt', 'is', 'a', '89', 'yo', 'male', 'with', 'sss', 's', '/', 'p', 'pacer', ',', 'admitted', 'to', 'neurosurgery', 'with', 'sdh', 'with', 'acute', 'respiratory', 'distress/', 'wheezing', 'on', 'the', 'floor', '.'], ['mild', 'right', 'ventricular', 'cavity', 'enlargement', 'with', 'normal', 'free', 'wall', 'motion', '.'], ['on', 'pod', 'six', ',', 'his', 'inr', 'continued', 'to', 'be', 'low', 'at', '1.3', 'but', 'it', 'was', 'decided', 'that', 'his', 'heparin', 'could', 'be', 'discontinued', 'and', 'he', 'would', 'be', 'discharged', 'home', 'with', 'po', 'coumadin', 'only', '.'], ['possibly', 'secondary', 'to', 'worsening', 'renal', 'function', ',', 'but', 'more', 'likely', 'due', 'to', 'acute', 'illness', '.'], ['she', 'progressed', 'with', 'physical', 'therapy', 'to', 'improve', 'her', 'strength', 'and', 'mobility', '.'], ['known', 'lastname', '28272', 'is', 'a', '63', 'year', '-', 'old', 'man', 'with', 'paf', ',', 'pvd', ',', 'hld', ',', 'htn', 'and', 'osa', 'with', 'complaint', 'of', 'several', 'months', 'of', 'exertional', 'chest', 'pain', 'and', 'dyspnea', '.'], ['pcp', 'sent', 'him', 'for', 'contrast', 'mri', ',', 'which', 'revealed', '15', '-', '20', 'ring', '-', 'enhancing', 'lesions', 'in', 'cerebrum', ',', 'cerebellum', ',', 'brainstem', '.'], ['the', 'patient', 'was', 'aggresively', 'diuresis', '4.5', 'litter', 'over', 'the', 'next', '36', 'hours', 'until', 'his', 'creatinine', 'bumped', 'and', 'he', 'was', 'at', 'his', 'dry', 'weight', '.'], ['megace', 'was', 'discontinued', 'due', 'to', 'the', 'possibility', 'that', 'this', 'may', 'contribute', 'to', 'the', 'formation', 'of', 'a', 'clot', '.'], ['his', 'wound', 'continued', 'to', 'improve', 'and', 'his', 'intravenous', 'antibiotics', 'were', 'stopped', '.'], ['in', 'the', 'ccu', ',', 'the', 'pt', 'was', 'resting', 'comfortably', 'in', 'nad', '.'], ['he', 'was', 'restarted', 'on', 'coumadin', ',', 'and', 'his', 'inr', 'was', 'therapeutic', 'for', 'a', 'few', 'days', 'before', 'admission', '.'], ['she', 'also', 'had', 'subjective', 'sob', 'with', 'cxr', 'suggesting', 'fluid', 'overload', '.'], ['later', ',', 'it', 'was', 'thought', 'that', 'his', 'oliguria', 'was', 'appropriate', 'for', 'his', 'nutritional', 'status', '.'], ['pt', 'started', 'to', 'complain', 'about', 'right', 'lower', 'quandrant', 'abdominal', 'pain', ',', 'radiating', 'to', 'right', 'flank', '.'], ['also', 'developed', 'cp', 'which', 'she', 'states', 'persisted', 'until', 'she', 'reached', 'the', 'ed', ',', 'when', 'she', 'was', 'given', 'some', 'medication', 'that', 'helped', '(', 'unsure', 'which', 'one', ')', '.'], ['the', 'mother', 'was', 'treated', 'with', 'ampicillin', 'and', 'received', 'betamethasone', '.'], ['there', 'was', 'no', 'change', 'noted', 'in', 'his', 'motor', 'sensory', 'function', '.'], ['a', 'bedside', 'echo', 'revealed', 'an', 'ef', 'of', '20', '%', '.'], ['-', 'most', 'likely', 'source', 'uti', 'with', 'subsequent', 'u ...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Source sent:  <SOS> he has hypertension . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# srcs[0]: 146
# srcs_mask: 1
# srcs_mask[0]: 1
# WHERE: 4
# Target Tokens:  he has hypertension .
# Out tokens:  he has high blood pressure .
# Source sent:  <SOS> take in for cxr . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# srcs[0]: 146
# srcs_mask: 1
# srcs_mask[0]: 1
# WHERE: 5
# Target Tokens:  take in for cxr .
# Out tokens:  take in for chest x - ray .
# Source sent:  <SOS> dr . <UNK> will see <UNK> . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# srcs[0]: 146
# srcs_mask: 1
# srcs_mask[0]: 1
# WHERE: 7
# Target Tokens:  dr . <UNK> will see <UNK> .
# Out tokens:  dr . patient will see ` ` .
# SENTENCES: ['he has high blood pressure .', 'take in for chest x - ray .', 'dr . patient will see ` ` .']
# COMBINED: he has high blood pressure. take in for chest x - ray. dr . patient will see ` `.
# 'he has high blood pressure. take in for chest x - ray. dr . patient will see ` `. '

# %%
# anvil.server.wait_forever()
# Out:
# {'original': ['hypertension.'], 'translated': ['hypertension.'], 'rephrased': ['hypertension.']}
# reached corpus sentence 0
# reached corpus sentence 0
# DATA: [['hypertension', '.']]
# TRAIN: [['weaned', 'off', 'vent', 'to', 'cpap', 'and', 'was', 'extubated', 'in', 'the', 'afternoon', 'on', '9', '-', '2', 'by', 'the', 'pulmonary', 'team', '.'], ['she', 'was', 'intubated', 'and', 'was', 'resuscitated', 'after', '10', '-', '22', 'minutes', 'of', 'pea', 'arrest', '.'], ['he', 'was', 'given', 'succinyl', 'choline', 'and', 'etomidate', 'for', 'intubation', '.'], ['had', 'post', '-', 'op', 'anemia', 'and', 'was', 'transfused', 'with', 'appropriate', 'effect', '.'], ['the', 'patient', 'was', 'maintained', 'on', 'logroll', 'precautions', 'until', 'tl', 'spine', 'films', 'were', 'obtained', 'and', 'read', 'as', 'negative', '.'], ['a', 'line', 'placed', '&', 'sent', 'to', 'mri', 'per', 'neurosurgical', 'recommendations', '.'], ['this', 'gradually', 'cleared', 'when', 'the', 'pt', 'was', 'extubated', 'and', 'by', 'the', 'last', 'few', 'days', 'of', 'admission', 'her', 'mental', 'status', 'was', 'at', 'baseline', '.'], ['per', 'patient', ',', 'he', 'took', 'pepto', '-', 'bismol', '3', 'times', 'earlier', 'in', 'the', 'weeks', 'for', '3', 'days', '.'], ['pt', 'is', 'a', '89', 'yo', 'male', 'with', 'sss', 's', '/', 'p', 'pacer', ',', 'admitted', 'to', 'neurosurgery', 'with', 'sdh', 'with', 'acute', 'respiratory', 'distress/', 'wheezing', 'on', 'the', 'floor', '.'], ['mild', 'right', 'ventricular', 'cavity', 'enlargement', 'with', 'normal', 'free', 'wall', 'motion', '.'], ['on', 'pod', 'six', ',', 'his', 'inr', 'continued', 'to', 'be', 'low', 'at', '1.3', 'but', 'it', 'was', 'decided', 'that', 'his', 'heparin', 'could', 'be', 'discontinued', 'and', 'he', 'would', 'be', 'discharged', 'home', 'with', 'po', 'coumadin', 'only', '.'], ['possibly', 'secondary', 'to', 'worsening', 'renal', 'function', ',', 'but', 'more', 'likely', 'due', 'to', 'acute', 'illness', '.'], ['she', 'progressed', 'with', 'physical', 'therapy', 'to', 'improve', 'her', 'strength', 'and', 'mobility', '.'], ['known', 'lastname', '28272', 'is', 'a', '63', 'year', '-', 'old', 'man', 'with', 'paf', ',', 'pvd', ',', 'hld', ',', 'htn', 'and', 'osa', 'with', 'complaint', 'of', 'several', 'months', 'of', 'exertional', 'chest', 'pain', 'and', 'dyspnea', '.'], ['pcp', 'sent', 'him', 'for', 'contrast', 'mri', ',', 'which', 'revealed', '15', '-', '20', 'ring', '-', 'enhancing', 'lesions', 'in', 'cerebrum', ',', 'cerebellum', ',', 'brainstem', '.'], ['the', 'patient', 'was', 'aggresively', 'diuresis', '4.5', 'litter', 'over', 'the', 'next', '36', 'hours', 'until', 'his', 'creatinine', 'bumped', 'and', 'he', 'was', 'at', 'his', 'dry', 'weight', '.'], ['megace', 'was', 'discontinued', 'due', 'to', 'the', 'possibility', 'that', 'this', 'may', 'contribute', 'to', 'the', 'formation', 'of', 'a', 'clot', '.'], ['his', 'wound', 'continued', 'to', 'improve', 'and', 'his', 'intravenous', 'antibiotics', 'were', 'stopped', '.'], ['in', 'the', 'ccu', ',', 'the', 'pt', 'was', 'resting', 'comfortably', 'in', 'nad', '.'], ['he', 'was', 'restarted', 'on', 'coumadin', ',', 'and', 'his', 'inr', 'was', 'therapeutic', 'for', 'a', 'few', 'days', 'before', 'admission', '.'], ['she', 'also', 'had', 'subjective', 'sob', 'with', 'cxr', 'suggesting', 'fluid', 'overload', '.'], ['later', ',', 'it', 'was', 'thought', 'that', 'his', 'oliguria', 'was', 'appropriate', 'for', 'his', 'nutritional', 'status', '.'], ['pt', 'started', 'to', 'complain', 'about', 'right', 'lower', 'quandrant', 'abdominal', 'pain', ',', 'radiating', 'to', 'right', 'flank', '.'], ['also', 'developed', 'cp', 'which', 'she', 'states', 'persisted', 'until', 'she', 'reached', 'the', 'ed', ',', 'when', 'she', 'was', 'given', 'some', 'medication', 'that', 'helped', '(', 'unsure', 'which', 'one', ')', '.'], ['the', 'mother', 'was', 'treated', 'with', 'ampicillin', 'and', 'received', 'betamethasone', '.'], ['there', 'was', 'no', 'change', 'noted', 'in', 'his', 'motor', 'sensory', 'function', '.'], ['a', 'bedside', 'echo', 'revealed', 'an', 'ef', 'of', '20', '%', '.'], ['-', 'most', 'likely', 'source', 'uti', 'with', 'subsequent', 'u ...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Source sent:  <SOS> hypertension . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# srcs[0]: 146
# srcs_mask: 1
# srcs_mask[0]: 1
# WHERE: 2
# Target Tokens:  hypertension .
# Out tokens:  high blood pressure .
# SENTENCES: ['high blood pressure .']
# COMBINED: high blood pressure .
# {'original': ['hypertension .'], 'translated': ['hypertension .'], 'rephrased': ['hypertension .']}
# reached corpus sentence 0
# reached corpus sentence 0
# DATA: [['hypertension', '.']]
# TRAIN: [['weaned', 'off', 'vent', 'to', 'cpap', 'and', 'was', 'extubated', 'in', 'the', 'afternoon', 'on', '9', '-', '2', 'by', 'the', 'pulmonary', 'team', '.'], ['she', 'was', 'intubated', 'and', 'was', 'resuscitated', 'after', '10', '-', '22', 'minutes', 'of', 'pea', 'arrest', '.'], ['he', 'was', 'given', 'succinyl', 'choline', 'and', 'etomidate', 'for', 'intubation', '.'], ['had', 'post', '-', 'op', 'anemia', 'and', 'was', 'transfused', 'with', 'appropriate', 'effect', '.'], ['the', 'patient', 'was', 'maintained', 'on', 'logroll', 'precautions', 'until', 'tl', 'spine', 'films', 'were', 'obtained', 'and', 'read', 'as', 'negative', '.'], ['a', 'line', 'placed', '&', 'sent', 'to', 'mri', 'per', 'neurosurgical', 'recommendations', '.'], ['this', 'gradually', 'cleared', 'when', 'the', 'pt', 'was', 'extubated', 'and', 'by', 'the', 'last', 'few', 'days', 'of', 'admission', 'her', 'mental', 'status', 'was', 'at', 'baseline', '.'], ['per', 'patient', ',', 'he', 'took', 'pepto', '-', 'bismol', '3', 'times', 'earlier', 'in', 'the', 'weeks', 'for', '3', 'days', '.'], ['pt', 'is', 'a', '89', 'yo', 'male', 'with', 'sss', 's', '/', 'p', 'pacer', ',', 'admitted', 'to', 'neurosurgery', 'with', 'sdh', 'with', 'acute', 'respiratory', 'distress/', 'wheezing', 'on', 'the', 'floor', '.'], ['mild', 'right', 'ventricular', 'cavity', 'enlargement', 'with', 'normal', 'free', 'wall', 'motion', '.'], ['on', 'pod', 'six', ',', 'his', 'inr', 'continued', 'to', 'be', 'low', 'at', '1.3', 'but', 'it', 'was', 'decided', 'that', 'his', 'heparin', 'could', 'be', 'discontinued', 'and', 'he', 'would', 'be', 'discharged', 'home', 'with', 'po', 'coumadin', 'only', '.'], ['possibly', 'secondary', 'to', 'worsening', 'renal', 'function', ',', 'but', 'more', 'likely', 'due', 'to', 'acute', 'illness', '.'], ['she', 'progressed', 'with', 'physical', 'therapy', 'to', 'improve', 'her', 'strength', 'and', 'mobility', '.'], ['known', 'lastname', '28272', 'is', 'a', '63', 'year', '-', 'old', 'man', 'with', 'paf', ',', 'pvd', ',', 'hld', ',', 'htn', 'and', 'osa', 'with', 'complaint', 'of', 'several', 'months', 'of', 'exertional', 'chest', 'pain', 'and', 'dyspnea', '.'], ['pcp', 'sent', 'him', 'for', 'contrast', 'mri', ',', 'which', 'revealed', '15', '-', '20', 'ring', '-', 'enhancing', 'lesions', 'in', 'cerebrum', ',', 'cerebellum', ',', 'brainstem', '.'], ['the', 'patient', 'was', 'aggresively', 'diuresis', '4.5', 'litter', 'over', 'the', 'next', '36', 'hours', 'until', 'his', 'creatinine', 'bumped', 'and', 'he', 'was', 'at', 'his', 'dry', 'weight', '.'], ['megace', 'was', 'discontinued', 'due', 'to', 'the', 'possibility', 'that', 'this', 'may', 'contribute', 'to', 'the', 'formation', 'of', 'a', 'clot', '.'], ['his', 'wound', 'continued', 'to', 'improve', 'and', 'his', 'intravenous', 'antibiotics', 'were', 'stopped', '.'], ['in', 'the', 'ccu', ',', 'the', 'pt', 'was', 'resting', 'comfortably', 'in', 'nad', '.'], ['he', 'was', 'restarted', 'on', 'coumadin', ',', 'and', 'his', 'inr', 'was', 'therapeutic', 'for', 'a', 'few', 'days', 'before', 'admission', '.'], ['she', 'also', 'had', 'subjective', 'sob', 'with', 'cxr', 'suggesting', 'fluid', 'overload', '.'], ['later', ',', 'it', 'was', 'thought', 'that', 'his', 'oliguria', 'was', 'appropriate', 'for', 'his', 'nutritional', 'status', '.'], ['pt', 'started', 'to', 'complain', 'about', 'right', 'lower', 'quandrant', 'abdominal', 'pain', ',', 'radiating', 'to', 'right', 'flank', '.'], ['also', 'developed', 'cp', 'which', 'she', 'states', 'persisted', 'until', 'she', 'reached', 'the', 'ed', ',', 'when', 'she', 'was', 'given', 'some', 'medication', 'that', 'helped', '(', 'unsure', 'which', 'one', ')', '.'], ['the', 'mother', 'was', 'treated', 'with', 'ampicillin', 'and', 'received', 'betamethasone', '.'], ['there', 'was', 'no', 'change', 'noted', 'in', 'his', 'motor', 'sensory', 'function', '.'], ['a', 'bedside', 'echo', 'revealed', 'an', 'ef', 'of', '20', '%', '.'], ['-', 'most', 'likely', 'source', 'uti', 'with', 'subsequent', 'u ...
# Source sent:  <SOS> hypertension . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# srcs[0]: 146
# srcs_mask: 1
# srcs_mask[0]: 1
# WHERE: 2
# Target Tokens:  hypertension .
# Out tokens:  high blood pressure .
# SENTENCES: ['high blood pressure .']
# COMBINED: high blood pressure .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-95cac3476493> in <module>()
# ----> 1 anvil.server.wait_forever()
#
# /usr/local/lib/python3.7/dist-packages/anvil/server.py in wait_forever()
#     338     _get_connection()
#     339     while True:
# --> 340         time.sleep(1)
#
# KeyboardInterrupt:
